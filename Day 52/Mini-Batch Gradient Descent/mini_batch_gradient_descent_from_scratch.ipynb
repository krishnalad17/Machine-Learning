# %%
from sklearn.datasets import load_diabetes
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import random

# %%
X,y=load_diabetes(return_X_y=True)

# %%
X.shape , y.shape
# Out:
# ((442, 10), (442,))

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
reg.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
y_pred=reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
class MBGDRegressor:

  def __init__(self,lr,epochs,batch_size):
    self.coef_=None
    self.intercept_=None
    self.lr=lr
    self.epochs=epochs
    self.batch_size=batch_size

  def fit(self,X_train,y_train):
    self.intercept_=0
    self.coef_=np.ones(X_train.shape[1])

    for i in range(self.epochs):
      for j in range(int(X_train.shape[0]/self.batch_size)):
        idx = random.sample(range(X_train.shape[0]),self.batch_size)

        y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_

        intercept_der = -2 * np.mean(y_train[idx] - y_hat)
        self.intercept_=self.intercept_ - (self.lr * intercept_der)

        coef_der = -2 * np.dot((y_train[idx] - y_hat),X_train[idx])
        self.coef_=self.coef_ - ((self.lr * coef_der))


  def predict(self,X_test):
    return np.dot(X_test,self.coef_) + self.intercept_

# %%
gd=MBGDRegressor(lr=0.1,epochs=50,batch_size=int(X_train.shape[0]/20))

# %%
import time

start=time.time()
gd.fit(X_train,y_train)
print('Time taken',time.time() - start)
# Out:
# Time taken 0.03975629806518555

# %%
gd.coef_
# Out:
# array([   7.3242723 , -222.26800766,  530.30092314,  329.26690337,
#         -90.73562496, -121.98999448, -194.367179  ,   59.6389444 ,
#         562.88940685,   43.82170049])

# %%
gd.intercept_
# Out:
# np.float64(151.21869629910898)

# %%
y_pred = gd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4422861034100882

# %%
from sklearn.linear_model import SGDRegressor

# %%
reg = SGDRegressor(max_iter=100,learning_rate='constant',eta0=0.02)

# %%
batch_size=10

for i in range(100):
  idx=random.sample(range(X_train.shape[0]),batch_size)
  reg.partial_fit(X_train[idx],y_train[idx])

# %%
reg.coef_
# Out:
# array([  59.66678523,  -54.72192845,  316.19633603,  227.75650438,
#          31.68533141,  -13.79788839, -163.0059202 ,  128.77053802,
#         302.33857087,  132.33401951])

# %%
reg.intercept_
# Out:
# array([150.49534298])

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.42274395729231884
