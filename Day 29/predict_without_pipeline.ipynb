# %%
import pickle
import numpy as np

# %%
ohe_sex=pickle.load(open('/content/models/ohe_sex.pkl','rb'))
ohe_embarked=pickle.load(open('/content/models/ohe_embarked.pkl','rb'))
clf=pickle.load(open('/content/models/clf.pkl','rb'))

# %%
test_input=np.array([2,'female',30,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'female', 30, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex=ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_embarked=ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_age=test_input[:,2].reshape(1,1)

# %%
test_tranformed=np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
clf.predict(test_tranformed)
# Out:
# array([1])
