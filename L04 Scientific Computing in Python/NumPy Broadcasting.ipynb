# %% [markdown]
# # NumPy Broadcasting

# %%
import numpy as np

a=np.array([1,2,3]) 
a+1  # numpy creates an arrays of 1 of equal length to array a for addition
# Out:
# array([2, 3, 4])

# %%
ary3=np.array([[4,5,6],[7,8,9]])

ary3 + a
# Out:
# array([[ 5,  7,  9],
#        [ 8, 10, 12]])
