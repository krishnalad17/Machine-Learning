# %% [markdown]
# ## NumPy Comparison Operator and Mask

# %%
import numpy as np

# %%
ary=np.array([1,2,3,4])
mask=ary>2
mask
# Out:
# array([False, False,  True,  True])

# %%
ary[mask] #it gives the values of the true indices
# Out:
# array([3, 4])

# %%
int(mask.sum())
# Out:
# np.int64(2)
